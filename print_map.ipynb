# %%
import folium
from folium.plugins import HeatMap
from os import system
import src.create_geoindex as geo

map_city=folium.Map(location=[37.3382,-121.8863], zoom_start=12)

collections = ["airport_sanjose_ca","elementary_school_sanjose_ca","kindergarten_sanjose_ca","night_clubs_sanjose_ca","starbucks_sanjose","train_stations_sanjose_ca","vegan_restaurants_sanjose_ca"]

# %%
db, coll = geo.connectCollection("companies","airport_sanjose_ca")
places = list(coll.find({"geometry.location.lat":{"$ne":None},"geometry.location.lng":{"$ne":None}}))

for place in places:
    folium.Marker(place['location']['coordinates'][::-1],
                radius=2,
                icon=folium.Icon(icon='plane',color='blue'), 
    ).add_to(map_city)

# %%
db, coll = geo.connectCollection("companies","night_clubs_sanjose_ca")
places = list(coll.find({"geometry.location.lat":{"$ne":None},"geometry.location.lng":{"$ne":None}}))

for place in places:
    folium.Marker(place['location'][0]['coordinates'][::-1],
                    radius=2,
                    icon=folium.Icon(icon='glass',color='purple'), 
                ).add_to(map_city)

# %%
db, coll = geo.connectCollection("companies","elementary_school_sanjose_ca")
places = list(coll.find({"geometry.location.lat":{"$ne":None},"geometry.location.lng":{"$ne":None}}))

for place in places:
    folium.Marker(place['location'][0]['coordinates'][::-1],
                    radius=2,
                    icon=folium.Icon(icon='school',color='black'), 
                ).add_to(map_city)

# %%
db, coll = geo.connectCollection("companies","kindergarten_sanjose_ca")
places = list(coll.find({"geometry.location.lat":{"$ne":None},"geometry.location.lng":{"$ne":None}}))

for place in places:
    folium.Marker(place['location'][0]['coordinates'][::-1],
                    radius=2,
                    icon=folium.Icon(icon='baby',color='white'), 
                ).add_to(map_city)

# %%
db, coll = geo.connectCollection("companies","train_stations_sanjose_ca")
places = list(coll.find({"geometry.location.lat":{"$ne":None},"geometry.location.lng":{"$ne":None}}))

for place in places:
    folium.Marker(place['location'][0]['coordinates'][::-1],
                    radius=2,
                    icon=folium.Icon(icon='train',color='red'), 
                ).add_to(map_city)

# %%
db, coll = geo.connectCollection("companies","starbucks_sanjose")
places = list(coll.find({"geometry.location.lat":{"$ne":None},"geometry.location.lng":{"$ne":None}}))

for place in places:
    folium.Marker(place['location'][0]['coordinates'][::-1],
                    radius=2,
                    icon=folium.Icon(icon='shop',color='darkgreen'), 
                ).add_to(map_city)

# %%
db, coll = geo.connectCollection("companies","vegan_restaurants_sanjose_ca")
places = list(coll.find({"geometry.location.lat":{"$ne":None},"geometry.location.lng":{"$ne":None}}))

for place in places:
    folium.Marker(place['location'][0]['coordinates'][::-1],
                    radius=2,
                    icon=folium.Icon(icon='leaf',color='lightgreen'), 
                ).add_to(map_city)

# %%
db, coll = geo.connectCollection("companies","startups_sanjose_ca")
places = list(coll.find({"geometry.location.lat":{"$ne":None},"geometry.location.lng":{"$ne":None}}))

for place in places:
    folium.Marker(place['location'][0]['coordinates'][::-1],
                    radius=2,
                    icon=folium.Icon(icon='cloud',color='gray'), 
                ).add_to(map_city)

# %%
'''
db, coll = geo.connectCollection('companies','companies')
companies = list(coll.find({"offices.city": "San Jose","founded_year": {"$lt": 2008},"offices.longitude":{"$ne":None},"offices.latitude":{"$ne": None}}))
for company in companies:
    folium.Marker(company['location'][0]['coordinates'][::-1],
                    radius=2,
                    icon=folium.Icon(icon='home',color='gray'), 
                   ).add_to(map_city)
'''
# Out:
# '\ndb, coll = geo.connectCollection(\'companies\',\'companies\')\ncompanies = list(coll.find({"offices.city": "San Jose","founded_year": {"$lt": 2008},"offices.longitude":{"$ne":None},"offices.latitude":{"$ne": None}}))\nfor company in companies:\n    folium.Marker(company[\'location\'][0][\'coordinates\'][::-1],\n                    radius=2,\n                    icon=folium.Icon(icon=\'home\',color=\'gray\'), \n                   ).add_to(map_city)\n'

# %%
map_city
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
